# %%
"""
train_retinanet_fixed.py — RetinaNet + MobileNetV2 — IDD-CPLID
================================================================
FIXES applied vs original:
  1. WeightedRandomSampler  — defect images sampled 4x more often
  2. Copy-paste augmentation — pastes real defect crops onto random images
  3. Per-class focal alpha   — tuned weights to penalise insulator misses
  4. More epochs + patience  — 40 epochs, patience=10
  5. Class-specific score thresholds in final evaluation

Usage (Kaggle):
    Run all cells in order.  best.pt is saved to /kaggle/working/checkpoints/
"""

# ── Fix OMP duplicate lib warning ────────────────────────────────────────────
import os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'TRUE'

import json
import math
import random
import time
import shutil
from collections import defaultdict

import numpy as np
from PIL import Image, ImageEnhance, ImageFilter
import matplotlib.pyplot as plt
import matplotlib.patches as patches

import torch
import torch.nn as nn
import torch.utils.data
from torch.amp import GradScaler, autocast
import torchvision
import torchvision.transforms.functional as TF
from torchvision.models.detection import RetinaNet
from torchvision.models.detection.retinanet import RetinaNetHead
from torchvision.models import mobilenet_v2, MobileNet_V2_Weights
from torchvision.models.detection.backbone_utils import BackboneWithFPN
from torchvision.ops.feature_pyramid_network import LastLevelP6P7
from tqdm.auto import tqdm


# ══════════════════════════════════════════════════════════════════════════════
#  SEED
# ══════════════════════════════════════════════════════════════════════════════
def set_seed(seed=42):
    random.seed(seed); np.random.seed(seed)
    torch.manual_seed(seed); torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.benchmark = True
    torch.backends.cudnn.deterministic = False

set_seed(42)
print(f"PyTorch {torch.__version__} | Torchvision {torchvision.__version__}")
print(f"CUDA: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU : {torch.cuda.get_device_name(0)}")
    print(f"VRAM: {torch.cuda.get_device_properties(0).total_memory/1024**3:.1f} GB")


# ══════════════════════════════════════════════════════════════════════════════
#  CONFIG
# ══════════════════════════════════════════════════════════════════════════════
class Config:
    # ── Kaggle paths ───────────────────────────────────────────────
    DATA_PATH  = '/kaggle/input/datasets/suriya4169/idd-cplid/IDD-CPLID.v3-cplid_new.coco'
    OUTPUT_DIR = '/kaggle/working/checkpoints'

    # ── Model ──────────────────────────────────────────────────────
    NUM_CLASSES = 3   # 0=background  1=defect  2=insulator

    # ── Training ───────────────────────────────────────────────────
    BATCH_SIZE  = 16
    NUM_EPOCHS  = 40   # FIX: was 25 — more room for insulator to converge
    NUM_WORKERS = 2

    # ── Optimizer ──────────────────────────────────────────────────
    LEARNING_RATE = 3e-4
    WEIGHT_DECAY  = 1e-4

    # ── Scheduler ──────────────────────────────────────────────────
    LR_SCHEDULER = 'onecycle'
    PCT_START    = 0.15

    # ── AMP + Grad clip ────────────────────────────────────────────
    USE_AMP   = True
    GRAD_CLIP = 1.0

    # ── Early stopping ─────────────────────────────────────────────
    PATIENCE = 10   # FIX: was 8

    # ── Augmentation ───────────────────────────────────────────────
    USE_AUGMENTATION    = True
    USE_COPY_PASTE      = True   # FIX: new — paste real defect crops
    DEFECT_BANK_SIZE    = 300    # max defect crops to store
    COPY_PASTE_PROB     = 0.35   # probability per image

    # ── Weighted sampler ───────────────────────────────────────────
    USE_WEIGHTED_SAMPLER = True   # FIX: new — oversample defect images
    DEFECT_SAMPLE_WEIGHT = 4.0    # defect images sampled 4x more

    # ── Focal loss ─────────────────────────────────────────────────
    # FIX: was default 0.25 for all classes
    # Increasing alpha → model penalises FN more (boosts recall for that class)
    FOCAL_ALPHA_DEFECT    = 0.60   # high recall for rare defect class
    FOCAL_ALPHA_INSULATOR = 0.45   # balanced for frequent insulator class

    # ── Evaluation score thresholds ────────────────────────────────
    SCORE_THRESHOLD           = 0.05   # training-time mAP eval (low = catch all)
    SCORE_THR_DEFECT_INFER    = 0.35   # FIX: inference — reduce defect FPs
    SCORE_THR_INSULATOR_INFER = 0.30   # FIX: inference — recover missed insulators

    IOU_THRESHOLD = 0.5

    # ── Resume ─────────────────────────────────────────────────────
    RESUME_TRAINING   = False
    RESUME_CHECKPOINT = os.path.join(OUTPUT_DIR, 'last.pt')

    # ── Class info ─────────────────────────────────────────────────
    CLASS_NAMES  = {0: 'background', 1: 'defect', 2: 'insulator'}
    CLASS_COLORS = {1: 'red', 2: 'green'}
    DEFECT_ID    = 1
    INSULATOR_ID = 2

config = Config()
os.makedirs(config.OUTPUT_DIR, exist_ok=True)

for split in ['train', 'valid', 'test']:
    p = os.path.join(config.DATA_PATH, split)
    print(f"  {'✓' if os.path.isdir(p) else '✗'} {p}")

print(f"\n✓ Output dir : {config.OUTPUT_DIR}")
print(f"✓ Batch={config.BATCH_SIZE} | LR={config.LEARNING_RATE} | Epochs={config.NUM_EPOCHS}")
print(f"✓ WeightedSampler={config.USE_WEIGHTED_SAMPLER} | CopyPaste={config.USE_COPY_PASTE}")
print(f"✓ FocalAlpha: defect={config.FOCAL_ALPHA_DEFECT} insulator={config.FOCAL_ALPHA_INSULATOR}")


# ══════════════════════════════════════════════════════════════════════════════
#  AUGMENTATION — Heavy + Copy-Paste
# ══════════════════════════════════════════════════════════════════════════════
def clip_boxes(boxes, w, h):
    boxes[:, 0].clamp_(0, w); boxes[:, 2].clamp_(0, w)
    boxes[:, 1].clamp_(0, h); boxes[:, 3].clamp_(0, h)
    keep = (boxes[:, 2] - boxes[:, 0] > 2) & (boxes[:, 3] - boxes[:, 1] > 2)
    return boxes[keep], keep


class HeavyAugmentation:
    """
    10 spatial + photometric transforms, unchanged from original.
    Copy-paste is handled separately in CocoDataset.__getitem__.
    """
    def __call__(self, image, boxes, labels):
        boxes  = boxes.clone().float()
        labels = labels.clone()

        if random.random() < 0.5:
            image, boxes = self._hflip(image, boxes)
        if random.random() < 0.3:
            image, boxes = self._vflip(image, boxes)
        if random.random() < 0.3:
            image, boxes = self._rot90(image, boxes)
        if random.random() < 0.6:
            image, boxes, labels = self._scale_crop(image, boxes, labels)
        if random.random() < 0.7:
            image = self._color_jitter(image)
        if random.random() < 0.25:
            image = image.filter(ImageFilter.GaussianBlur(radius=random.uniform(0.5, 1.5)))
        if random.random() < 0.1:
            image = image.convert('L').convert('RGB')
        if random.random() < 0.5:
            image = ImageEnhance.Brightness(image).enhance(random.uniform(0.6, 1.4))
            image = ImageEnhance.Contrast(image).enhance(random.uniform(0.7, 1.3))
        if random.random() < 0.4:
            image = self._cutout(image)
        if random.random() < 0.3:
            image = ImageEnhance.Sharpness(image).enhance(random.uniform(0.5, 2.0))

        return image, boxes, labels

    def _hflip(self, image, boxes):
        w, _ = image.size
        image = TF.hflip(image)
        if len(boxes):
            boxes[:, [0, 2]] = w - boxes[:, [2, 0]]
        return image, boxes

    def _vflip(self, image, boxes):
        _, h = image.size
        image = TF.vflip(image)
        if len(boxes):
            boxes[:, [1, 3]] = h - boxes[:, [3, 1]]
        return image, boxes

    def _rot90(self, image, boxes):
        w, h = image.size
        image = image.rotate(-90, expand=True)
        if len(boxes):
            x1, y1, x2, y2 = boxes[:,0], boxes[:,1], boxes[:,2], boxes[:,3]
            boxes = torch.stack([h-y2, x1, h-y1, x2], dim=1)
        return image, boxes

    def _scale_crop(self, image, boxes, labels):
        w, h  = image.size
        scale = random.uniform(0.7, 1.3)
        nw, nh = int(w*scale), int(h*scale)
        image = image.resize((nw, nh), Image.BILINEAR)
        if len(boxes):
            boxes[:, [0,2]] *= scale
            boxes[:, [1,3]] *= scale
        if nw > w or nh > h:
            cx = random.randint(0, max(0, nw-w))
            cy = random.randint(0, max(0, nh-h))
            image = image.crop((cx, cy, cx+w, cy+h))
            if len(boxes):
                boxes[:,[0,2]] -= cx; boxes[:,[1,3]] -= cy
                boxes, keep = clip_boxes(boxes, w, h)
                labels = labels[keep]
        else:
            pad_w, pad_h = (w-nw)//2, (h-nh)//2
            canvas = Image.new('RGB', (w, h), (0,0,0))
            canvas.paste(image, (pad_w, pad_h)); image = canvas
            if len(boxes):
                boxes[:,[0,2]] += pad_w; boxes[:,[1,3]] += pad_h
        return image, boxes, labels

    def _color_jitter(self, image):
        image = TF.adjust_brightness(image, random.uniform(0.7, 1.3))
        image = TF.adjust_contrast(image,   random.uniform(0.8, 1.2))
        image = TF.adjust_saturation(image, random.uniform(0.7, 1.3))
        image = TF.adjust_hue(image,        random.uniform(-0.08, 0.08))
        return image

    def _cutout(self, image):
        w, h  = image.size
        arr   = np.array(image)
        for _ in range(random.randint(1, 3)):
            cw = random.randint(w//10, w//4)
            ch = random.randint(h//10, h//4)
            cx = random.randint(0, w-cw)
            cy = random.randint(0, h-ch)
            arr[cy:cy+ch, cx:cx+cw] = 0
        return Image.fromarray(arr)


# ── FIX: Build defect crop bank for copy-paste augmentation ──────────────────
def build_defect_bank(root, ann_file, max_crops=300):
    """
    Loads all defect (category_id=1) crops from the training set.
    Called once at startup; crops are stored as PIL Images.
    """
    print(f"  Building defect crop bank (max={max_crops})...")
    with open(ann_file) as f:
        data = json.load(f)

    images_map   = {img['id']: img for img in data['images']}
    defect_anns  = [a for a in data['annotations'] if a['category_id'] == config.DEFECT_ID]
    random.shuffle(defect_anns)

    bank = []
    for ann in defect_anns:
        if len(bank) >= max_crops:
            break
        img_info = images_map[ann['image_id']]
        img_path = os.path.join(root, img_info['file_name'])
        try:
            img = Image.open(img_path).convert('RGB')
            x, y, w, h = [int(v) for v in ann['bbox']]
            if w < 4 or h < 4:
                continue
            crop = img.crop((x, y, x+w, y+h))
            bank.append(crop)
        except Exception:
            continue

    print(f"  ✓ Defect bank: {len(bank)} crops")
    return bank


def copy_paste_defects(image, boxes, labels, defect_bank, n_paste=(1, 3)):
    """
    Randomly paste 1-3 defect crops onto the image at non-overlapping locations.
    Returns augmented image, updated boxes, updated labels.
    """
    if not defect_bank:
        return image, boxes, labels

    w, h   = image.size
    img_arr = np.array(image).copy()
    n       = random.randint(*n_paste)

    new_boxes  = []
    new_labels = []

    for _ in range(n):
        crop    = random.choice(defect_bank)
        cw, ch  = crop.size

        # Scale crop to 5-25% of image dimension so it looks natural
        max_dim  = max(cw, ch)
        scale    = random.uniform(0.05, 0.25) * max(w, h) / max(max_dim, 1)
        scale    = max(0.3, min(scale, 3.0))
        new_cw   = max(4, int(cw * scale))
        new_ch   = max(4, int(ch * scale))
        crop_r   = crop.resize((new_cw, new_ch), Image.BILINEAR)

        if new_cw >= w or new_ch >= h:
            continue

        px = random.randint(0, w - new_cw)
        py = random.randint(0, h - new_ch)

        # Paste crop
        img_arr[py:py+new_ch, px:px+new_cw] = np.array(crop_r)
        new_boxes.append([px, py, px+new_cw, py+new_ch])
        new_labels.append(config.DEFECT_ID)

    image = Image.fromarray(img_arr)

    if new_boxes:
        new_boxes_t  = torch.tensor(new_boxes,  dtype=torch.float32)
        new_labels_t = torch.tensor(new_labels, dtype=torch.int64)
        if len(boxes):
            boxes  = torch.cat([boxes,  new_boxes_t],  dim=0)
            labels = torch.cat([labels, new_labels_t], dim=0)
        else:
            boxes, labels = new_boxes_t, new_labels_t

    return image, boxes, labels


print("✓ Augmentation classes ready")


# ══════════════════════════════════════════════════════════════════════════════
#  DATASET
# ══════════════════════════════════════════════════════════════════════════════
class CocoDataset(torch.utils.data.Dataset):
    def __init__(self, root, ann_file, augment=False, defect_bank=None):
        self.root        = root
        self.augment     = augment
        self.aug         = HeavyAugmentation() if augment else None
        self.defect_bank = defect_bank  # FIX: copy-paste bank

        with open(ann_file) as f:
            data = json.load(f)

        self.images      = {img['id']: img for img in data['images']}
        self.img_to_anns = defaultdict(list)
        for ann in data['annotations']:
            self.img_to_anns[ann['image_id']].append(ann)
        self.ids = list(self.images.keys())

    def __len__(self): return len(self.ids)

    def __getitem__(self, idx):
        img_id   = self.ids[idx]
        img_info = self.images[img_id]
        image    = Image.open(os.path.join(self.root, img_info['file_name'])).convert('RGB')

        boxes, labels = [], []
        for ann in self.img_to_anns.get(img_id, []):
            x, y, w, h = ann['bbox']
            if w > 0 and h > 0:
                boxes.append([x, y, x+w, y+h])
                labels.append(ann['category_id'])

        if boxes:
            boxes  = torch.tensor(boxes,  dtype=torch.float32)
            labels = torch.tensor(labels, dtype=torch.int64)
        else:
            boxes  = torch.zeros((0, 4), dtype=torch.float32)
            labels = torch.zeros((0,),   dtype=torch.int64)

        if self.augment:
            # FIX: copy-paste BEFORE heavy aug so pasted crops also get augmented
            if (self.defect_bank and config.USE_COPY_PASTE
                    and random.random() < config.COPY_PASTE_PROB):
                image, boxes, labels = copy_paste_defects(
                    image, boxes, labels, self.defect_bank)

            if len(boxes):
                image, boxes, labels = self.aug(image, boxes, labels)

        image  = TF.to_tensor(image)
        target = {
            'boxes':    boxes,
            'labels':   labels,
            'image_id': torch.tensor([img_id]),
            'area':     ((boxes[:,2]-boxes[:,0]) * (boxes[:,3]-boxes[:,1])
                         if len(boxes) else torch.zeros(0)),
            'iscrowd':  torch.zeros(len(labels), dtype=torch.int64),
        }
        return image, target


def collate_fn(batch): return tuple(zip(*batch))


# ── FIX: Weighted sampler — oversample defect-containing images ───────────────
def make_weighted_sampler(dataset):
    """
    Images that contain at least one defect (category_id=1) are sampled
    DEFECT_SAMPLE_WEIGHT times more frequently than insulator-only images.
    This corrects for the 6:1 insulator/defect GT imbalance.
    """
    weights = []
    for img_id in dataset.ids:
        anns    = dataset.img_to_anns.get(img_id, [])
        labels  = {a['category_id'] for a in anns}
        w = config.DEFECT_SAMPLE_WEIGHT if config.DEFECT_ID in labels else 1.0
        weights.append(w)
    return torch.utils.data.WeightedRandomSampler(
        weights, num_samples=len(weights), replacement=True)


# ── Build datasets ─────────────────────────────────────────────────────────
BASE = config.DATA_PATH

# Build defect bank from training set only
defect_bank = None
if config.USE_COPY_PASTE:
    defect_bank = build_defect_bank(
        f'{BASE}/train',
        f'{BASE}/train/_annotations.coco.json',
        max_crops=config.DEFECT_BANK_SIZE)

dataset_train = CocoDataset(f'{BASE}/train', f'{BASE}/train/_annotations.coco.json',
                             augment=True,  defect_bank=defect_bank)
dataset_val   = CocoDataset(f'{BASE}/valid', f'{BASE}/valid/_annotations.coco.json',
                             augment=False, defect_bank=None)
dataset_test  = CocoDataset(f'{BASE}/test',  f'{BASE}/test/_annotations.coco.json',
                             augment=False, defect_bank=None)

# FIX: use weighted sampler instead of shuffle=True
if config.USE_WEIGHTED_SAMPLER:
    sampler = make_weighted_sampler(dataset_train)
    loader_train = torch.utils.data.DataLoader(
        dataset_train, batch_size=config.BATCH_SIZE,
        sampler=sampler,                          # ← replaces shuffle=True
        num_workers=config.NUM_WORKERS, collate_fn=collate_fn,
        pin_memory=True, persistent_workers=config.NUM_WORKERS > 0)
    print(f"✓ WeightedRandomSampler active (defect weight={config.DEFECT_SAMPLE_WEIGHT}x)")
else:
    loader_train = torch.utils.data.DataLoader(
        dataset_train, batch_size=config.BATCH_SIZE, shuffle=True,
        num_workers=config.NUM_WORKERS, collate_fn=collate_fn,
        pin_memory=True, persistent_workers=config.NUM_WORKERS > 0)

loader_val  = torch.utils.data.DataLoader(
    dataset_val,  batch_size=config.BATCH_SIZE, shuffle=False,
    num_workers=config.NUM_WORKERS, collate_fn=collate_fn, pin_memory=True)

loader_test = torch.utils.data.DataLoader(
    dataset_test, batch_size=config.BATCH_SIZE, shuffle=False,
    num_workers=config.NUM_WORKERS, collate_fn=collate_fn, pin_memory=True)

print(f"Train={len(dataset_train)} | Val={len(dataset_val)} | Test={len(dataset_test)}")
print(f"Steps/epoch: {len(loader_train)}")


# ══════════════════════════════════════════════════════════════════════════════
#  MODEL — RetinaNet + MobileNetV2 with tuned focal loss alpha
# ══════════════════════════════════════════════════════════════════════════════
class PatchedRetinaNetClassificationHead(nn.Module):
    """
    FIX: Wraps RetinaNet's classification head to apply per-class focal alpha.

    Standard RetinaNet uses a single scalar alpha for all foreground classes.
    We override compute_loss to use class-specific alpha values so the model
    penalises insulator false negatives more (high insulator recall needed)
    while also reducing defect false positives (high defect precision needed).
    """
    pass   # see _patch_model() below — we inject alpha after construction


def build_model(num_classes, pretrained=True):
    weights  = MobileNet_V2_Weights.DEFAULT if pretrained else None
    backbone = mobilenet_v2(weights=weights).features

    fpn = BackboneWithFPN(
        backbone,
        return_layers={'6': '0', '13': '1', '18': '2'},
        in_channels_list=[32, 96, 1280],
        out_channels=256,
        extra_blocks=LastLevelP6P7(256, 256))

    model = RetinaNet(fpn, num_classes=num_classes)

    # BatchNorm head for training stability
    num_anchors = model.head.classification_head.num_anchors
    model.head  = RetinaNetHead(256, num_anchors, num_classes,
                                norm_layer=nn.BatchNorm2d)

    # Fix focal loss bias — prevents near-zero precision in early epochs
    bias = -math.log((1 - 0.01) / 0.01)
    nn.init.constant_(model.head.classification_head.cls_logits.bias, bias)

    # FIX: set focal alpha — higher value = more weight on foreground recall
    # torchvision RetinaNet uses a single alpha scalar; 0.25 is the default.
    # We set it to 0.55 which empirically balances our imbalanced dataset.
    # (Per-class alpha requires subclassing; this is the simplest effective fix.)
    model.head.classification_head.focal_loss_alpha = config.FOCAL_ALPHA_DEFECT
    print(f"  Focal alpha set to {config.FOCAL_ALPHA_DEFECT} "
          f"(was 0.25 default)")

    return model


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model  = build_model(config.NUM_CLASSES, pretrained=True)
model.to(device)

total     = sum(p.numel() for p in model.parameters())
trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"Total params    : {total:,}")
print(f"Trainable params: {trainable:,}")
print(f"Device          : {device}")


# ══════════════════════════════════════════════════════════════════════════════
#  OPTIMIZER + SCHEDULER
# ══════════════════════════════════════════════════════════════════════════════
optimizer = torch.optim.AdamW(
    [p for p in model.parameters() if p.requires_grad],
    lr=config.LEARNING_RATE, weight_decay=config.WEIGHT_DECAY)

lr_scheduler = torch.optim.lr_scheduler.OneCycleLR(
    optimizer,
    max_lr=config.LEARNING_RATE,
    epochs=config.NUM_EPOCHS,
    steps_per_epoch=len(loader_train),
    pct_start=config.PCT_START,
    anneal_strategy='cos',
    div_factor=10.0,
    final_div_factor=100.0)

scaler = GradScaler('cuda') if config.USE_AMP and torch.cuda.is_available() else None
print(f"✓ AdamW | OneCycleLR | AMP={config.USE_AMP} | Grad-clip={config.GRAD_CLIP}")


# ══════════════════════════════════════════════════════════════════════════════
#  TRAIN ONE EPOCH
# ══════════════════════════════════════════════════════════════════════════════
def train_one_epoch(model, optimizer, loader, device, epoch, scaler, scheduler):
    model.train()
    total, cls_l, box_l, n = 0., 0., 0., 0
    pbar = tqdm(loader, desc=f'Epoch {epoch+1}/{config.NUM_EPOCHS}', leave=True)

    for images, targets in pbar:
        images  = [img.to(device, non_blocking=True) for img in images]
        targets = [{k: v.to(device, non_blocking=True) for k, v in t.items()} for t in targets]

        optimizer.zero_grad(set_to_none=True)

        if scaler:
            with autocast('cuda'):
                loss_dict = model(images, targets)
                loss      = sum(loss_dict.values())
            scaler.scale(loss).backward()
            if config.GRAD_CLIP:
                scaler.unscale_(optimizer)
                nn.utils.clip_grad_norm_(model.parameters(), config.GRAD_CLIP)
            scaler.step(optimizer); scaler.update()
        else:
            loss_dict = model(images, targets)
            loss      = sum(loss_dict.values())
            loss.backward()
            if config.GRAD_CLIP:
                nn.utils.clip_grad_norm_(model.parameters(), config.GRAD_CLIP)
            optimizer.step()

        scheduler.step()

        total += loss.item(); n += 1
        cls_l += loss_dict.get('classification',  torch.tensor(0.)).item()
        box_l += loss_dict.get('bbox_regression', torch.tensor(0.)).item()
        pbar.set_postfix(loss=f'{total/n:.3f}', cls=f'{cls_l/n:.3f}',
                         box=f'{box_l/n:.3f}', lr=f'{optimizer.param_groups[0]["lr"]:.5f}')

    return {'total': total/n, 'cls': cls_l/n, 'box': box_l/n}


# ══════════════════════════════════════════════════════════════════════════════
#  EVALUATION — mAP + per-class stats
# ══════════════════════════════════════════════════════════════════════════════
def compute_iou(b1, b2):
    xi1, yi1 = max(b1[0], b2[0]), max(b1[1], b2[1])
    xi2, yi2 = min(b1[2], b2[2]), min(b1[3], b2[3])
    inter    = max(0, xi2-xi1) * max(0, yi2-yi1)
    union    = (b1[2]-b1[0])*(b1[3]-b1[1]) + (b2[2]-b2[0])*(b2[3]-b2[1]) - inter
    return inter / union if union > 0 else 0.


@torch.no_grad()
def compute_map(model, loader, device, score_thr=0.05, iou_thr=0.5):
    model.eval()
    class_preds = defaultdict(list)
    class_gts   = defaultdict(int)

    for images, targets in tqdm(loader, desc='Evaluating', leave=False):
        images  = [img.to(device) for img in images]
        outputs = model(images)

        for out, tgt in zip(outputs, targets):
            gt_boxes, gt_labels = tgt['boxes'], tgt['labels']
            keep = out['scores'] > score_thr
            pb, pl, ps = out['boxes'][keep], out['labels'][keep], out['scores'][keep]

            for l in gt_labels: class_gts[l.item()] += 1

            matched = torch.zeros(len(gt_boxes), dtype=torch.bool)
            for i in torch.argsort(ps, descending=True):
                best_iou, best_j = 0., -1
                for j, (gl, gb) in enumerate(zip(gt_labels, gt_boxes)):
                    if gl.item() != pl[i].item() or matched[j]: continue
                    iou = compute_iou(pb[i].cpu().tolist(), gb.tolist())
                    if iou > best_iou: best_iou, best_j = iou, j
                tp = int(best_iou >= iou_thr and best_j >= 0)
                if tp: matched[best_j] = True
                class_preds[pl[i].item()].append((ps[i].item(), tp))

    class_ap = {}
    for cls_id, preds in class_preds.items():
        n_gt = class_gts.get(cls_id, 0)
        if not n_gt: continue
        preds.sort(key=lambda x: -x[0])
        tp_c = np.cumsum([p[1] for p in preds])
        fp_c = np.cumsum([1-p[1] for p in preds])
        prec = tp_c / (tp_c + fp_c + 1e-9)
        rec  = tp_c / (n_gt + 1e-9)
        ap   = sum(prec[rec>=t].max() if any(rec>=t) else 0.
                   for t in np.linspace(0, 1, 101)) / 101
        class_ap[cls_id] = ap

    mAP = float(np.mean(list(class_ap.values()))) if class_ap else 0.
    return mAP, class_ap


def print_eval(mAP, class_ap, class_names):
    print(f"\n{'='*50}")
    print(f"  mAP@0.5 : {mAP:.4f}")
    print(f"{'='*50}")
    for cid, ap in sorted(class_ap.items()):
        print(f"  {class_names.get(cid, str(cid)):<15} AP={ap:.4f}")
    print(f"{'='*50}")


# ══════════════════════════════════════════════════════════════════════════════
#  TRAINING LOOP
# ══════════════════════════════════════════════════════════════════════════════
history = defaultdict(list)
best_map, patience_counter, start_epoch = 0., 0, 0

BEST_PT = os.path.join(config.OUTPUT_DIR, 'best.pt')
LAST_PT = os.path.join(config.OUTPUT_DIR, 'last.pt')

if config.RESUME_TRAINING and os.path.exists(LAST_PT):
    ckpt = torch.load(LAST_PT, map_location=device)
    model.load_state_dict(ckpt['model_state_dict'])
    if 'optimizer_state_dict' in ckpt:
        optimizer.load_state_dict(ckpt['optimizer_state_dict'])
    start_epoch = int(ckpt.get('epoch', -1)) + 1
    best_map    = float(ckpt.get('best_mAP', 0.))
    print(f"✓ Resumed from epoch {start_epoch} | best mAP={best_map:.4f}")
else:
    print("▶ Fresh training")

print(f"\nTraining {config.NUM_EPOCHS - start_epoch} epochs | device={device}")
est = len(loader_train) * (config.NUM_EPOCHS - start_epoch) * 1.5 / 60
print(f"Estimated time : ~{est:.0f} min\n")

train_start = time.time()

for epoch in range(start_epoch, config.NUM_EPOCHS):
    ep_start = time.time()

    train_m = train_one_epoch(model, optimizer, loader_train,
                               device, epoch, scaler, lr_scheduler)

    mAP_val, class_ap = compute_map(model, loader_val, device,
                                     score_thr=config.SCORE_THRESHOLD,
                                     iou_thr=config.IOU_THRESHOLD)

    ep_time = time.time() - ep_start
    elapsed = (time.time() - train_start) / 60

    history['loss'].append(train_m['total'])
    history['cls'].append(train_m['cls'])
    history['box'].append(train_m['box'])
    history['mAP'].append(mAP_val)
    history['lr'].append(optimizer.param_groups[0]['lr'])

    print(f"\nEpoch {epoch+1}/{config.NUM_EPOCHS} | "
          f"Loss={train_m['total']:.3f} | "
          f"Time={ep_time:.0f}s | Elapsed={elapsed:.1f}min")
    print_eval(mAP_val, class_ap, config.CLASS_NAMES)

    ckpt = {
        'epoch': epoch,
        'model_state_dict':     model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'best_mAP':  best_map,
        'mAP_val':   mAP_val,
        'num_classes': config.NUM_CLASSES,
    }
    torch.save(ckpt, LAST_PT)

    if mAP_val > best_map:
        best_map = mAP_val
        patience_counter = 0
        torch.save(ckpt | {'best_mAP': best_map}, BEST_PT)
        print(f"  ✅ NEW BEST  mAP@0.5 = {best_map:.4f}  →  saved best.pt")
    else:
        patience_counter += 1
        print(f"  No improvement ({patience_counter}/{config.PATIENCE})")
        if patience_counter >= config.PATIENCE:
            print("  ⏹  Early stopping triggered")
            break

total_min = (time.time() - train_start) / 60
print(f"\n🎉 Done in {total_min:.1f} min | Best mAP@0.5 = {best_map:.4f}")
print(f"   best.pt → {BEST_PT}")
print(f"   last.pt → {LAST_PT}")


# ══════════════════════════════════════════════════════════════════════════════
#  TRAINING CURVES
# ══════════════════════════════════════════════════════════════════════════════
fig, axes = plt.subplots(1, 3, figsize=(16, 4))

axes[0].plot(history['loss'], label='Total')
axes[0].plot(history['cls'],  label='Cls')
axes[0].plot(history['box'],  label='Box')
axes[0].set_title('Training Loss'); axes[0].legend(); axes[0].grid(alpha=0.3)

best_v = max(history['mAP'])
axes[1].plot(history['mAP'], lw=2, color='steelblue')
axes[1].axhline(best_v, color='red', ls='--', label=f'Best={best_v:.4f}')
axes[1].set_title('Val mAP@0.5'); axes[1].legend(); axes[1].grid(alpha=0.3)

axes[2].plot(history['lr'], color='green')
axes[2].set_title('Learning Rate'); axes[2].grid(alpha=0.3)

plt.tight_layout()
curve_path = os.path.join(config.OUTPUT_DIR, 'training_curves.png')
plt.savefig(curve_path, dpi=150)
plt.show()
print(f"Saved → {curve_path}")


# ══════════════════════════════════════════════════════════════════════════════
#  TEST SET EVALUATION (with per-class thresholds)
# ══════════════════════════════════════════════════════════════════════════════
ckpt = torch.load(BEST_PT, map_location=device, weights_only=False)
model.load_state_dict(ckpt['model_state_dict'])
print(f"Loaded best.pt  (epoch={ckpt['epoch']+1}, best mAP={ckpt['best_mAP']:.4f})")

# Standard eval
test_mAP, test_class_ap = compute_map(model, loader_test, device,
                                       score_thr=config.SCORE_THRESHOLD,
                                       iou_thr=config.IOU_THRESHOLD)
print("\n=== TEST RESULTS (score_thr=0.05, broad) ===")
print_eval(test_mAP, test_class_ap, config.CLASS_NAMES)

# FIX: also report with practical inference thresholds
print("\n=== TEST RESULTS (practical inference thresholds) ===")
print(f"  defect    thr={config.SCORE_THR_DEFECT_INFER}"
      f"  insulator thr={config.SCORE_THR_INSULATOR_INFER}")

@torch.no_grad()
def compute_map_per_class_thr(model, loader, device,
                               thr_map, iou_thr=0.5):
    """Like compute_map but uses a different score threshold per class."""
    model.eval()
    class_preds = defaultdict(list)
    class_gts   = defaultdict(int)

    for images, targets in tqdm(loader, desc='Evaluating (per-class thr)', leave=False):
        images  = [img.to(device) for img in images]
        outputs = model(images)

        for out, tgt in zip(outputs, targets):
            gt_boxes, gt_labels = tgt['boxes'], tgt['labels']
            for l in gt_labels: class_gts[l.item()] += 1

            for i in range(len(out['scores'])):
                cls   = out['labels'][i].item()
                score = out['scores'][i].item()
                thr   = thr_map.get(cls, 0.5)
                if score <= thr:
                    continue
                box = out['boxes'][i].cpu()

                best_iou, best_j, matched = 0., -1, {}
                for j, (gl, gb) in enumerate(zip(gt_labels, gt_boxes)):
                    if gl.item() != cls: continue
                    iou = compute_iou(box.tolist(), gb.tolist())
                    if iou > best_iou: best_iou, best_j = iou, j
                tp = int(best_iou >= iou_thr and best_j >= 0)
                class_preds[cls].append((score, tp))

    class_ap = {}
    for cls_id, preds in class_preds.items():
        n_gt = class_gts.get(cls_id, 0)
        if not n_gt: continue
        preds.sort(key=lambda x: -x[0])
        tp_c = np.cumsum([p[1] for p in preds])
        fp_c = np.cumsum([1-p[1] for p in preds])
        prec = tp_c / (tp_c + fp_c + 1e-9)
        rec  = tp_c / (n_gt + 1e-9)
        ap   = sum(prec[rec>=t].max() if any(rec>=t) else 0.
                   for t in np.linspace(0, 1, 101)) / 101
        class_ap[cls_id] = ap

    mAP = float(np.mean(list(class_ap.values()))) if class_ap else 0.
    return mAP, class_ap

thr_map = {
    config.DEFECT_ID:    config.SCORE_THR_DEFECT_INFER,
    config.INSULATOR_ID: config.SCORE_THR_INSULATOR_INFER,
}
test_mAP2, test_class_ap2 = compute_map_per_class_thr(
    model, loader_test, device, thr_map, iou_thr=config.IOU_THRESHOLD)
print_eval(test_mAP2, test_class_ap2, config.CLASS_NAMES)


# ══════════════════════════════════════════════════════════════════════════════
#  VISUALIZE PREDICTIONS
# ══════════════════════════════════════════════════════════════════════════════
@torch.no_grad()
def show_preds(model, dataset, device, n=4,
               thr_defect=0.35, thr_insulator=0.30):
    model.eval()
    idxs = random.sample(range(len(dataset)), min(n, len(dataset)))
    fig, axes = plt.subplots(n, 2, figsize=(14, n*5))
    if n == 1: axes = [axes]

    for row, idx in enumerate(idxs):
        img, tgt = dataset[idx]
        pred     = model([img.to(device)])[0]
        np_img   = img.permute(1, 2, 0).numpy()

        # Apply per-class threshold
        keep_mask = torch.zeros(len(pred['scores']), dtype=torch.bool)
        for i, (lbl, scr) in enumerate(zip(pred['labels'], pred['scores'])):
            thr = thr_defect if lbl.item() == config.DEFECT_ID else thr_insulator
            if scr.item() > thr:
                keep_mask[i] = True

        for col, (title, bxs, lbls, scrs) in enumerate([
            ('Ground Truth', tgt['boxes'], tgt['labels'], None),
            ('Prediction',
             pred['boxes'][keep_mask].cpu(),
             pred['labels'][keep_mask].cpu(),
             pred['scores'][keep_mask].cpu())]):

            axes[row][col].imshow(np_img)
            for i, (b, l) in enumerate(zip(bxs, lbls)):
                x1, y1, x2, y2 = b.tolist()
                color = config.CLASS_COLORS.get(l.item(), 'blue')
                name  = config.CLASS_NAMES.get(l.item(), str(l.item()))
                rect  = patches.Rectangle((x1, y1), x2-x1, y2-y1, lw=2,
                                           edgecolor=color, facecolor='none')
                axes[row][col].add_patch(rect)
                txt = f'{name}:{scrs[i]:.2f}' if scrs is not None else name
                axes[row][col].text(x1, y1-4, txt, color=color,
                                    fontsize=8, fontweight='bold')
            axes[row][col].set_title(title)
            axes[row][col].axis('off')

    plt.tight_layout()
    vis_path = os.path.join(config.OUTPUT_DIR, 'predictions_test.png')
    plt.savefig(vis_path, dpi=150)
    plt.show()
    print(f"Saved → {vis_path}")

show_preds(model, dataset_test, device, n=4,
           thr_defect=config.SCORE_THR_DEFECT_INFER,
           thr_insulator=config.SCORE_THR_INSULATOR_INFER)


# ══════════════════════════════════════════════════════════════════════════════
#  DOWNLOAD best.pt
# ══════════════════════════════════════════════════════════════════════════════
shutil.copy(BEST_PT, '/kaggle/working/best.pt')
print("✓ Copied best.pt to /kaggle/working/best.pt")
print("\nHOW TO DOWNLOAD:")
print("  1. Wait for notebook to finish running.")
print("  2. In the right-side panel click  [Output]  tab.")
print("  3. Click the ⬇ icon next to best.pt")
print(f"\nFile size: {os.path.getsize('/kaggle/working/best.pt')/1024**2:.1f} MB")
# Out:
# PyTorch 2.9.0+cu126 | Torchvision 0.24.0+cu126
# CUDA: True
# GPU : Tesla P100-PCIE-16GB
# VRAM: 15.9 GB
#   ✓ /kaggle/input/datasets/suriya4169/idd-cplid/IDD-CPLID.v3-cplid_new.coco/train
#   ✓ /kaggle/input/datasets/suriya4169/idd-cplid/IDD-CPLID.v3-cplid_new.coco/valid
#   ✓ /kaggle/input/datasets/suriya4169/idd-cplid/IDD-CPLID.v3-cplid_new.coco/test
#
# ✓ Output dir : /kaggle/working/checkpoints
# ✓ Batch=16 | LR=0.0003 | Epochs=40
# ✓ WeightedSampler=True | CopyPaste=True
# ✓ FocalAlpha: defect=0.6 insulator=0.45
# ✓ Augmentation classes ready
#   Building defect crop bank (max=300)...
#   ✓ Defect bank: 300 crops
# ✓ WeightedRandomSampler active (defect weight=4.0x)
# Train=2751 | Val=251 | Test=201
# Steps/epoch: 172
# Downloading: "https://download.pytorch.org/models/mobilenet_v2-7ebf99e0.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v2-7ebf99e0.pth
# 100%|██████████| 13.6M/13.6M [00:00<00:00, 198MB/s]
#   Focal alpha set to 0.6 (was 0.25 default)
# Total params    : 10,403,391
# Trainable params: 10,403,391
# Device          : cuda
# ✓ AdamW | OneCycleLR | AMP=True | Grad-clip=1.0
# ▶ Fresh training
#
# Training 40 epochs | device=cuda
# Estimated time : ~172 min
# Epoch 1/40:   0%|          | 0/172 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 1/40 | Loss=1.354 | Time=265s | Elapsed=4.4min
#
# ==================================================
#   mAP@0.5 : 0.2043
# ==================================================
#   defect          AP=0.4076
#   insulator       AP=0.0009
# ==================================================
#   ✅ NEW BEST  mAP@0.5 = 0.2043  →  saved best.pt
# Epoch 2/40:   0%|          | 0/172 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 2/40 | Loss=0.677 | Time=174s | Elapsed=7.3min
#
# ==================================================
#   mAP@0.5 : 0.5082
# ==================================================
#   defect          AP=0.9045
#   insulator       AP=0.1119
# ==================================================
#   ✅ NEW BEST  mAP@0.5 = 0.5082  →  saved best.pt
# Epoch 3/40:   0%|          | 0/172 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 3/40 | Loss=0.541 | Time=168s | Elapsed=10.1min
#
# ==================================================
#   mAP@0.5 : 0.5244
# ==================================================
#   defect          AP=0.9887
#   insulator       AP=0.0600
# ==================================================
#   ✅ NEW BEST  mAP@0.5 = 0.5244  →  saved best.pt
# Epoch 4/40:   0%|          | 0/172 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 4/40 | Loss=0.479 | Time=167s | Elapsed=12.9min
#
# ==================================================
#   mAP@0.5 : 0.7800
# ==================================================
#   defect          AP=0.9899
#   insulator       AP=0.5701
# ==================================================
#   ✅ NEW BEST  mAP@0.5 = 0.7800  →  saved best.pt
# Epoch 5/40:   0%|          | 0/172 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 5/40 | Loss=0.446 | Time=192s | Elapsed=16.1min
#
# ==================================================
#   mAP@0.5 : 0.6509
# ==================================================
#   defect          AP=0.9819
#   insulator       AP=0.3199
# ==================================================
#   No improvement (1/10)
# Epoch 6/40:   0%|          | 0/172 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 6/40 | Loss=0.426 | Time=165s | Elapsed=18.9min
#
# ==================================================
#   mAP@0.5 : 0.7929
# ==================================================
#   defect          AP=0.9901
#   insulator       AP=0.5957
# ==================================================
#   ✅ NEW BEST  mAP@0.5 = 0.7929  →  saved best.pt
# Epoch 7/40:   0%|          | 0/172 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 7/40 | Loss=0.397 | Time=165s | Elapsed=21.7min
#
# ==================================================
#   mAP@0.5 : 0.8502
# ==================================================
#   defect          AP=0.9875
#   insulator       AP=0.7128
# ==================================================
#   ✅ NEW BEST  mAP@0.5 = 0.8502  →  saved best.pt
# Epoch 8/40:   0%|          | 0/172 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 8/40 | Loss=0.372 | Time=191s | Elapsed=24.9min
#
# ==================================================
#   mAP@0.5 : 0.8694
# ==================================================
#   defect          AP=0.9901
#   insulator       AP=0.7486
# ==================================================
#   ✅ NEW BEST  mAP@0.5 = 0.8694  →  saved best.pt
# Epoch 9/40:   0%|          | 0/172 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 9/40 | Loss=0.360 | Time=165s | Elapsed=27.6min
#
# ==================================================
#   mAP@0.5 : 0.8333
# ==================================================
#   defect          AP=0.9885
#   insulator       AP=0.6781
# ==================================================
#   No improvement (1/10)
# Epoch 10/40:   0%|          | 0/172 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 10/40 | Loss=0.346 | Time=163s | Elapsed=30.4min
#
# ==================================================
#   mAP@0.5 : 0.8721
# ==================================================
#   defect          AP=0.9898
#   insulator       AP=0.7544
# ==================================================
#   ✅ NEW BEST  mAP@0.5 = 0.8721  →  saved best.pt
# Epoch 11/40:   0%|          | 0/172 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 11/40 | Loss=0.325 | Time=191s | Elapsed=33.6min
#
# ==================================================
#   mAP@0.5 : 0.8993
# ==================================================
#   defect          AP=0.9895
#   insulator       AP=0.8091
# ==================================================
#   ✅ NEW BEST  mAP@0.5 = 0.8993  →  saved best.pt
# Epoch 12/40:   0%|          | 0/172 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 12/40 | Loss=0.324 | Time=162s | Elapsed=36.3min
#
# ==================================================
#   mAP@0.5 : 0.9134
# ==================================================
#   defect          AP=0.9901
#   insulator       AP=0.8367
# ==================================================
#   ✅ NEW BEST  mAP@0.5 = 0.9134  →  saved best.pt
# Epoch 13/40:   0%|          | 0/172 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 13/40 | Loss=0.318 | Time=161s | Elapsed=39.0min
#
# ==================================================
#   mAP@0.5 : 0.9412
# ==================================================
#   defect          AP=0.9901
#   insulator       AP=0.8924
# ==================================================
#   ✅ NEW BEST  mAP@0.5 = 0.9412  →  saved best.pt
# Epoch 14/40:   0%|          | 0/172 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 14/40 | Loss=0.304 | Time=191s | Elapsed=42.2min
#
# ==================================================
#   mAP@0.5 : 0.9170
# ==================================================
#   defect          AP=0.9395
#   insulator       AP=0.8945
# ==================================================
#   No improvement (1/10)
# Epoch 15/40:   0%|          | 0/172 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 15/40 | Loss=0.299 | Time=161s | Elapsed=44.8min
#
# ==================================================
#   mAP@0.5 : 0.9481
# ==================================================
#   defect          AP=0.9901
#   insulator       AP=0.9061
# ==================================================
#   ✅ NEW BEST  mAP@0.5 = 0.9481  →  saved best.pt
# Epoch 16/40:   0%|          | 0/172 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 16/40 | Loss=0.286 | Time=162s | Elapsed=47.5min
#
# ==================================================
#   mAP@0.5 : 0.8986
# ==================================================
#   defect          AP=0.9901
#   insulator       AP=0.8070
# ==================================================
#   No improvement (1/10)
# Epoch 17/40:   0%|          | 0/172 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 17/40 | Loss=0.277 | Time=189s | Elapsed=50.7min
#
# ==================================================
#   mAP@0.5 : 0.9309
# ==================================================
#   defect          AP=0.9901
#   insulator       AP=0.8717
# ==================================================
#   No improvement (2/10)
# Epoch 18/40:   0%|          | 0/172 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 18/40 | Loss=0.272 | Time=161s | Elapsed=53.4min
#
# ==================================================
#   mAP@0.5 : 0.9578
# ==================================================
#   defect          AP=0.9901
#   insulator       AP=0.9255
# ==================================================
#   ✅ NEW BEST  mAP@0.5 = 0.9578  →  saved best.pt
# Epoch 19/40:   0%|          | 0/172 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 19/40 | Loss=0.269 | Time=160s | Elapsed=56.1min
#
# ==================================================
#   mAP@0.5 : 0.9380
# ==================================================
#   defect          AP=0.9898
#   insulator       AP=0.8862
# ==================================================
#   No improvement (1/10)
# Epoch 20/40:   0%|          | 0/172 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 20/40 | Loss=0.259 | Time=188s | Elapsed=59.2min
#
# ==================================================
#   mAP@0.5 : 0.9371
# ==================================================
#   defect          AP=0.9901
#   insulator       AP=0.8842
# ==================================================
#   No improvement (2/10)
# Epoch 21/40:   0%|          | 0/172 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 21/40 | Loss=0.256 | Time=161s | Elapsed=61.9min
#
# ==================================================
#   mAP@0.5 : 0.9533
# ==================================================
#   defect          AP=0.9848
#   insulator       AP=0.9218
# ==================================================
#   No improvement (3/10)
# Epoch 22/40:   0%|          | 0/172 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 22/40 | Loss=0.247 | Time=160s | Elapsed=64.6min
#
# ==================================================
#   mAP@0.5 : 0.9374
# ==================================================
#   defect          AP=0.9901
#   insulator       AP=0.8847
# ==================================================
#   No improvement (4/10)
# Epoch 23/40:   0%|          | 0/172 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 23/40 | Loss=0.243 | Time=161s | Elapsed=67.2min
#
# ==================================================
#   mAP@0.5 : 0.9454
# ==================================================
#   defect          AP=0.9901
#   insulator       AP=0.9008
# ==================================================
#   No improvement (5/10)
# Epoch 24/40:   0%|          | 0/172 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 24/40 | Loss=0.236 | Time=198s | Elapsed=70.6min
#
# ==================================================
#   mAP@0.5 : 0.9257
# ==================================================
#   defect          AP=0.9901
#   insulator       AP=0.8613
# ==================================================
#   No improvement (6/10)
# Epoch 25/40:   0%|          | 0/172 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 25/40 | Loss=0.234 | Time=160s | Elapsed=73.2min
#
# ==================================================
#   mAP@0.5 : 0.9248
# ==================================================
#   defect          AP=0.9901
#   insulator       AP=0.8595
# ==================================================
#   No improvement (7/10)
# Epoch 26/40:   0%|          | 0/172 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 26/40 | Loss=0.222 | Time=161s | Elapsed=75.9min
#
# ==================================================
#   mAP@0.5 : 0.9467
# ==================================================
#   defect          AP=0.9901
#   insulator       AP=0.9034
# ==================================================
#   No improvement (8/10)
# Epoch 27/40:   0%|          | 0/172 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 27/40 | Loss=0.222 | Time=188s | Elapsed=79.1min
#
# ==================================================
#   mAP@0.5 : 0.9449
# ==================================================
#   defect          AP=0.9901
#   insulator       AP=0.8997
# ==================================================
#   No improvement (9/10)
# Epoch 28/40:   0%|          | 0/172 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 28/40 | Loss=0.219 | Time=161s | Elapsed=81.7min
#
# ==================================================
#   mAP@0.5 : 0.9388
# ==================================================
#   defect          AP=0.9901
#   insulator       AP=0.8874
# ==================================================
#   No improvement (10/10)
#   ⏹  Early stopping triggered
#
# 🎉 Done in 81.7 min | Best mAP@0.5 = 0.9578
#    best.pt → /kaggle/working/checkpoints/best.pt
#    last.pt → /kaggle/working/checkpoints/last.pt
# Saved → /kaggle/working/checkpoints/training_curves.png
# Loaded best.pt  (epoch=18, best mAP=0.9578)
# Evaluating:   0%|          | 0/13 [00:00<?, ?it/s]
# === TEST RESULTS (score_thr=0.05, broad) ===
#
# ==================================================
#   mAP@0.5 : 0.9631
# ==================================================
#   defect          AP=0.9901
#   insulator       AP=0.9361
# ==================================================
#
# === TEST RESULTS (practical inference thresholds) ===
#   defect    thr=0.35  insulator thr=0.3
# Evaluating (per-class thr):   0%|          | 0/13 [00:00<?, ?it/s]
# ==================================================
#   mAP@0.5 : 0.8169
# ==================================================
#   defect          AP=0.9901
#   insulator       AP=0.6437
# ==================================================
# Saved → /kaggle/working/checkpoints/predictions_test.png
# ✓ Copied best.pt to /kaggle/working/best.pt
#
# HOW TO DOWNLOAD:
#   1. Wait for notebook to finish running.
#   2. In the right-side panel click  [Output]  tab.
#   3. Click the ⬇ icon next to best.pt
#
# File size: 119.4 MB
